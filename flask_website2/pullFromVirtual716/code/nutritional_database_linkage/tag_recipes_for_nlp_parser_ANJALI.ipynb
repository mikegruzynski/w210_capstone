# %%
import json
import pandas as pd
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import numpy as np
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.preprocessing.text import Tokenizer
import keras.preprocessing.text as kpt
import keras
import re 
import numpy, time
import random
import pickle
from keras.models import load_model, model_from_json
import random
# Out:
# height has been deprecated.
# Using TensorFlow backend.

# %%
def transform_data_for_tokenizer(recipe_item):
    original = recipe_item.lower()
    original = re.sub(r'\s*(\d+|[./+*-])', '', original)
    original_split = original.split(" ")
    remove_list = list(set(original).symmetric_difference(units_of_food_recipe))

    keep_list = []
    for i in original_split:
        if i not in food_size and i not in units_of_food_recipe:
            keep_list.append(i)
    
    original_split = list(filter(None, keep_list))
    new = " ".join(original_split)
    return new

# %%
units_of_food_recipe = ["cups", "cup", "c.", "c", 
                        "fl. oz.", "fl oz", "fluid ounce", "fluid ounces",
                        "gal", "gal.", "gallon", "gallons",
                        "oz", "oz.", "ounce", "ounces", "ouncs",
                        "pt", "pt.", "pint", "pints",
                        "lb", "lb.", "pound", "pounds",
                        "qt", "qt.", "qts", "qts.", "quart", "quarts",
                        "tbsp.", "tbsp", "T", "T.", "tablespoon", "tablespoons", "tbs.", "tbs",
                        "tsp.", "tsp", "t", "t.", "teaspoon", "teaspoons",
                        "g", "g.", "gr", "gr.", "gram", "grams", "gramme", "grammes",
                        "kg", "kg.", "kilogram", "kilograms", "kilogramme", "kilogrammes",
                        "l", "l.", "liter", "liters", "litre", "litres",
                        "mg", "mg.", "milligram", "milligrams", "milligramme", "milligrammes",
                        "ml", "ml.", "milliliter", "milliliters", "millilitre", "millilitres",
                        "pinch", "pinches", "dash", "dashes", "touch", "touches", "handful", "handfuls",
                        "stick", "sticks",
                        "cans", "can",
                        "to taste",
                        "scoop", "scoops",
                        "dollop", "dollops",
                        "sprig", "sprigs",
                       "recipe",
                       "garnish", "garnished",
                       "sprinkle", "spinkled",
                       "slices",
                       "serving", "servings",
                       "ribs", "rib", "stalk",
                       "inch", "inches", "in.",
                       "drizzle", "drizzled",
                       "to taste"]

food_size = ["small", "medium",
              "large", "about"]

food_format = ["slice", "sliced",
              "dice", "diced",
              "peel", "peeled",
              "chop", "chopped",
              "julienne", "julienned",
              "trim", "trimmed",
              "sift", "sifted",
              "freshly",
              "fine", "finely",
              "drain", "drained",
              "super thinly", "thin", "thinly",
              "grate", "grated",
              "seeded",
              "rinse", "rinsed",
              "smash", "smashed",
              "membrane", "removed",
              "cleaned",
              "mince", "minced",
              "crush", "crushed",
              "about", "around",
              '<hr>']


def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
# nlp_df = pd.read_csv("../../data/nutrient/compiled/train_nn_df.csv", index_col=0)
nlp_df = pd.read_csv("../../data/nutrient/compiled/train_nn_df_ANJALI.csv", index_col=0)
master_df = pd.read_csv("../../data/nutrient/compiled/nutrition_master_df.csv")

with open('../../data/recipe/recipe_all.json') as f:
    recipe_all = json.load(f)
    
with open('/root/w210_capstone/data/models/NDB_tag_unique_unique_dict.json') as f:
        NDB_tag_unique_unique_dict = json.load(f)

# loading
with open('/root/w210_capstone/data/models/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
    
# load json and create model
json_file = open('/root/w210_capstone/data/models/model_simple_nn.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# load weights into new model
loaded_model.load_weights("/root/w210_capstone/data/models/model_simple_nn_WEIGHTS.h5")
print("Loaded model from disk")

ambiguous = pd.read_csv("/root/w210_capstone/data/recipe/ambiguous_conversion.csv")
# Out:
# Loaded model from disk

# %%
random.seed(time.time())
ids = np.unique(list(recipe_all.keys()))
random.shuffle(ids)

original_text_list = []
NDB_ID_list = []
Description_list = []

for recipe_id in ids[:5]:
    print('\n')
    print(recipe_id)
    
    for ingredient in recipe_all[recipe_id]['ingredients']:
        print(ingredient)
        ingredient_filtered = transform_data_for_tokenizer(ingredient)
        tokens = tokenizer.texts_to_matrix([ingredient_filtered])
        n = 3
        prediction = loaded_model.predict(np.array(tokens))

        index_top_3_list =  loaded_model.predict(np.array(tokens)).argsort()[0][-n:][::-1]
        NDB_top_3_list = []
        percentage_top_3_list = []
        for i in index_top_3_list:   
            for key in NDB_tag_unique_unique_dict.keys():        
                if NDB_tag_unique_unique_dict[key] == i:
                    NDB_top_3_list.append(key)
                    percentage_top_3_list.append(prediction[0][i])

        itr = 0
        while itr < 3:            
            print('\t', NDB_top_3_list[itr], round(percentage_top_3_list[itr], 4), master_df[master_df['NDB_NO'] == "\"{}\"".format(NDB_top_3_list[itr].strip('"'))]['Description'].get_values()[0])
            itr += 1
        
        print('\n')
        
        raw_input_return = input()
        
        if raw_input_return == 'exit':
            break
        
        else:
            if raw_input_return:
                if raw_input_return != 'np.nan':
                    original_text_list.append(ingredient)
                    NDB_ID_list.append(raw_input_return)
                    Description_list.append(master_df[master_df['NDB_NO'] == "\"{}\"".format(raw_input_return.strip('"'))]['Description'].get_values()[0])
            else:
                if raw_input_return != 'np.nan':
                    original_text_list.append(ingredient)
                    NDB_ID_list.append(NDB_top_3_list[0])
                    Description_list.append(master_df[master_df['NDB_NO'] == "\"{}\"".format(NDB_top_3_list[0].strip('"'))]['Description'].get_values()[0])
                

temp_df = pd.DataFrame([original_text_list, NDB_ID_list, Description_list]).transpose()
temp_df.columns = nlp_df.columns
temp_df = temp_df.dropna()
nlp_df_new = pd.concat([nlp_df, temp_df])
nlp_df_new.to_csv("../../data/nutrient/compiled/train_nn_df_ANJALI.csv")
nlp_df = pd.read_csv("../../data/nutrient/compiled/train_nn_df_ANJALI.csv", index_col=0)
# Out:
# RECIPE_56751
# Two 1-pound salmon fillets
# 	 "15238" 0.9957 fish, salmon, coho, farmed, raw
# 	 "15077" 0.0028 fish, salmon, chinook, smoked
# 	 "15261" 0.0002 fish, tilapia, raw
#
#
#
# 1 tablespoon soy sauce
# 	 "16124" 0.5921 soy sauce made from soy (tamari)
# 	 "16424" 0.3569 soy sauce made from soy and wheat (shoyu), low sodium
# 	 "16123" 0.0115 soy sauce made from soy and wheat (shoyu)
#
#
#
# 1/4 teaspoon salt
# 	 "02047" 0.9981 salt, table
# 	 "10165" 0.0009 pork, cured, salt pork, raw
# 	 "02020" 0.0003 spices, garlic powder
#
#
#
# 1/8 teaspoon ground white pepper
# 	 "02032" 0.9758 spices, pepper, white
# 	 "02030" 0.0177 spices, pepper, black
# 	 "20020" 0.0008 cornmeal, whole-grain, yellow
#
#
#
# 2 scallions cut into 4-inch pieces
# 	 "11291" 0.9979 onions, spring or scallions (includes tops and bulb), raw
# 	 "11282" 0.0003 onions, raw
# 	 "11109" 0.0003 cabbage, raw
#
#
#
# 4 slices ginger
# 	 "11216" 0.9875 ginger root, raw
# 	 "02021" 0.0097 spices, ginger, ground
# 	 "31033" 0.001 ginger root, pickled, canned, with artificial sweetener
#
#
#
# 1 lemon
# 	 "09150" 0.9807 lemons, raw, without peel
# 	 "09152" 0.0089 lemon juice, raw
# 	 "09156" 0.0049 lemon peel, raw
#
#
#
# 2 teaspoons sesame oil
# 	 "04058" 0.9809 oil, sesame, salad or cooking
# 	 "44005" 0.0062 oil, corn, peanut, and olive
# 	 "12698" 0.0041 seeds, sesame butter, tahini, type of kernels unspecified
#
#
#
#
#
# RECIPE_63574
# 1/2 cup dry red wine
# 	 "14096" 0.7786 alcoholic beverage, wine, table, red
# 	 "14106" 0.0952 alcoholic beverage, wine, table, white
# 	 "14097" 0.0311 alcoholic beverage, wine, table, red, cabernet sauvignon
#
#
#
# 1/4 cup good quality port (preferably not too sweet)
# 	 "02028" 0.2572 spices, paprika
# 	 "19095" 0.0697 ice creams, vanilla
# 	 "01053" 0.0598 cream, fluid, heavy whipping
#
#
# "14096"
# 1/4 cup olive oil
# 	 "44005" 0.9916 oil, corn, peanut, and olive
# 	 "04708" 0.0042 mayonnaise, reduced fat, with olive oil
# 	 "16087" 0.0021 peanuts, all types, raw
#
#
#
# 2 tablespoons balsamic vinegar
# 	 "02069" 0.9737 vinegar, balsamic
# 	 "02053" 0.0157 vinegar, distilled
# 	 "02048" 0.0044 vinegar, cider
#
#
#
# 2 tablespoons maple syrup
# 	 "19353" 0.9979 syrups, maple
# 	 "09043" 0.0002 blackberry juice, canned
# 	 "19912" 0.0002 sweetener, syrup, agave
#
#
#
# 2 tablespoons low-salt soy sauce
# 	 "16424" 0.783 soy sauce made from soy and wheat (shoyu), low sodium
# 	 "16124" 0.1459 soy sauce made from soy (tamari)
# 	 "16123" 0.0172 soy sauce made from soy and wheat (shoyu)
#
#
#
# 2 bay leaves
# 	 "02004" 0.9681 spices, bay leaf
# 	 "20120" 0.0042 pasta, dry, enriched
# 	 "02038" 0.0023 spices, sage, ground
#
#
#
# 1 teaspoon cracked black pepper
# 	 "02030" 0.9992 spices, pepper, black
# 	 "02032" 0.0002 spices, pepper, white
# 	 "02006" 0.0002 spices, cardamom
#
#
#
# 2 cloves garlic crushed
# 	 "11215" 0.9982 garlic, raw
# 	 "02011" 0.0009 spices, cloves, ground
# 	 "02020" 0.0007 spices, garlic powder
#
#
#
# Several sprigs of fresh thyme or 1/4 teaspoon dried thyme
# 	 "02049" 0.963 thyme, fresh
# 	 "02042" 0.0333 spices, thyme, dried
# 	 "02027" 0.0012 spices, oregano, dried
#
#
#
# 1/2 teaspoon juniper berries
# 	 "09316" 0.9773 strawberries, raw
# 	 "11124" 0.0024 carrots, raw
# 	 "11007" 0.0014 artichokes, (globe or french), raw
#
#
#
# 8 quail preferably fresh with breast and backbones removed
# 	 "05057" 0.5018 chicken, broilers or fryers, breast, meat and skin, raw
# 	 "05011" 0.1455 chicken, broilers or fryers, meat only, raw
# 	 "02044" 0.0672 basil, fresh
#
#
# "05159"
# 2 tablespoons olive oil
# 	 "44005" 0.9916 oil, corn, peanut, and olive
# 	 "04708" 0.0042 mayonnaise, reduced fat, with olive oil
# 	 "16087" 0.0021 peanuts, all types, raw
#
#
#
# 2 pounds poultry bones necks and wing tips (quail chicken duck or any combination of the three)
# 	 "05062" 0.2407 chicken, broiler or fryers, breast, skinless, boneless, meat only, raw
# 	 "05057" 0.1262 chicken, broilers or fryers, breast, meat and skin, raw
# 	 "05011" 0.1142 chicken, broilers or fryers, meat only, raw
#
#
#
# 2 carrots roughly chopped (about 1/2 cup)
# 	 "11124" 0.9812 carrots, raw
# 	 "11960" 0.014 carrots, baby, raw
# 	 "11583" 0.0006 vegetables, mixed, frozen, unprepared
#
#
#
# 1 onion diced (about 1/2 cup)
# 	 "11282" 0.9952 onions, raw
# 	 "11291" 0.003 onions, spring or scallions (includes tops and bulb), raw
# 	 "11294" 0.0009 onions, sweet, raw
#
#
#
# 3 ribs celery roughly chopped (about 3/4 cup)
# 	 "11143" 0.9735 celery, raw
# 	 "02007" 0.0204 spices, celery seed
# 	 "11591" 0.0019 watercress, raw
#
#
#
# 1 bay leaf
# 	 "02004" 0.9848 spices, bay leaf
# 	 "08506" 0.0015 cereals ready-to-eat, ralston corn flakes
# 	 "02038" 0.0015 spices, sage, ground
#
#
#
# 1/2 teaspoon dried thyme
# 	 "02042" 0.6277 spices, thyme, dried
# 	 "02049" 0.3606 thyme, fresh
# 	 "02027" 0.0039 spices, oregano, dried
#
#
#
# 1 clove garlic crushed with the flat of a knife blade
# 	 "11215" 0.9983 garlic, raw
# 	 "02020" 0.0011 spices, garlic powder
# 	 "02011" 0.0003 spices, cloves, ground
#
#
#
# 3 quarts water
# 	 "14411" 0.9969 beverages, water, tap, drinking
# 	 "11588" 0.0014 waterchestnuts, chinese, (matai), raw
# 	 "11590" 0.0003 waterchestnuts, chinese, canned, solids and liquids
#
#
#
# 1/2 cup veal stock or beef stock
# 	 "06170" 0.984 soup, stock, beef, home-prepared
# 	 "06700" 0.0046 soup, vegetable broth, ready to serve
# 	 "06172" 0.0032 soup, stock, chicken, home-prepared
#
#
#
# 1 cup good quality port
# 	 "19904" 0.109 chocolate, dark, 70-85% cacao solids
# 	 "19165" 0.0903 cocoa, dry powder, unsweetened
# 	 "20120" 0.0726 pasta, dry, enriched
#
#
# "14096"
# 2 tablespoons good quality port
# 	 "19904" 0.109 chocolate, dark, 70-85% cacao solids
# 	 "19165" 0.0903 cocoa, dry powder, unsweetened
# 	 "20120" 0.0726 pasta, dry, enriched
#
#
# "14096"
# 2 tablespoons unsalted butter
# 	 "01145" 0.9989 butter, without salt
# 	 "01001" 0.0006 butter, salted
# 	 "12151" 0.0001 nuts, pistachio nuts, raw
#
#
#
#
#
# RECIPE_84185
# 4 cups dashi
# 	 "14037" 0.0494 alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 80 proof
# 	 "14096" 0.0354 alcoholic beverage, wine, table, red
# 	 "09202" 0.0285 oranges, raw, navels (includes foods for usda's food distribution program)
#
#
#
# 1/2 cup sliced shiitake mushrooms
# 	 "11238" 0.9254 mushrooms, shiitake, raw
# 	 "11260" 0.047 mushrooms, white, raw
# 	 "06625" 0.0058 smart soup, vietnamese carrot lemongrass
#
#
#
# 4 tablespoons red miso
# 	 "11821" 0.2364 peppers, sweet, red, raw
# 	 "11282" 0.202 onions, raw
# 	 "16112" 0.1573 miso
#
#
# "16112"
# 10 ounces tofu cut into 1/2-inch cubes
# 	 "18349" 0.1635 rolls, french
# 	 "18029" 0.095 bread, french or vienna (includes sourdough)
# 	 "11352" 0.0902 potatoes, flesh and skin, raw
#
#
# "16162"
# Chopped green onions for garnish
# 	 "11291" 0.985 onions, spring or scallions (includes tops and bulb), raw
# 	 "11282" 0.0127 onions, raw
# 	 "11156" 0.0004 chives, raw
#
#
#
# 3 quarts cold water
# 	 "14411" 0.9965 beverages, water, tap, drinking
# 	 "11588" 0.0007 waterchestnuts, chinese, (matai), raw
# 	 "19095" 0.0006 ice creams, vanilla
#
#
#
# 3 ounces giant kelp (kombu)
# 	 "11445" 0.8473 seaweed, kelp, raw
# 	 "04708" 0.0189 mayonnaise, reduced fat, with olive oil
# 	 "01123" 0.0114 egg, whole, raw, fresh
#
#
# "11445"
# 3 ounces dried bonito flakes
# 	 "02031" 0.3395 spices, pepper, red or cayenne
# 	 "15123" 0.2873 fish, tuna, fresh, skipjack, raw
# 	 "07019" 0.0836 sausage, pork, chorizo, link or ground, raw
#
#
#
#
#
# RECIPE_7690
# 2 bay leaves
# 	 "02004" 0.9681 spices, bay leaf
# 	 "20120" 0.0042 pasta, dry, enriched
# 	 "02038" 0.0023 spices, sage, ground
#
#
#
# 1/3 cup sugar
# 	 "19335" 0.9831 sugars, granulated
# 	 "28293" 0.0088 cookie, butter or sugar, with chocolate icing or filling
# 	 "19336" 0.0032 sugars, powdered
#
#
#
# Pinch of kosher salt
# 	 "02047" 0.9993 salt, table
# 	 "10165" 0.0003 pork, cured, salt pork, raw
# 	 "02020" 0.0002 spices, garlic powder
#
#
#
# 2 teaspoons fresh lemon juice
# 	 "09152" 0.989 lemon juice, raw
# 	 "09150" 0.0077 lemons, raw, without peel
# 	 "09153" 0.0011 lemon juice from concentrate, canned or bottled
#
#
#
# 3/4 cup (1 1/2 sticks) unsalted butter melted slightly cooled plus more for pan
# 	 "01145" 0.9991 butter, without salt
# 	 "01001" 0.0006 butter, salted
# 	 "04501" 0.0001 oil, cocoa butter
#
#
#
# 1 1/2 cups coarse-grind semolina flour
# 	 "20581" 0.9975 wheat flour, white, all-purpose, enriched, unbleached
# 	 "20082" 0.0015 wheat flour, white, all-purpose, self-rising, enriched
# 	 "20080" 0.0004 wheat flour, whole-grain (includes foods for usda's food distribution program)
#
#
#
# 1 cup sugar
# 	 "19335" 0.9831 sugars, granulated
# 	 "28293" 0.0088 cookie, butter or sugar, with chocolate icing or filling
# 	 "19336" 0.0032 sugars, powdered
# 2 teaspoons baking powder
# 	 "18371" 0.6714 leavening agents, baking powder, low-sodium
# 	 "18370" 0.1961 leavening agents, baking powder, double-acting, straight phosphate
# 	 "11157" 0.0368 chrysanthemum, garland, raw
#
#
#
# 2 teaspoons finely grated orange zest
# 	 "09203" 0.9767 oranges, raw, florida
# 	 "42270" 0.0048 beverages, orange juice drink
# 	 "09202" 0.0044 oranges, raw, navels (includes foods for usda's food distribution program)
#
#
# "09216"
# 1 teaspoon ground cardamom
# 	 "02006" 0.9922 spices, cardamom
# 	 "13786" 0.0018 beef, chuck eye roast, boneless, america's beef roast, separable lean and fat, trimmed to 0" fat, all grades, raw
# 	 "02030" 0.0011 spices, pepper, black
#
#
#
# 1/2 teaspoon kosher salt
# 	 "02047" 0.9994 salt, table
# 	 "10165" 0.0003 pork, cured, salt pork, raw
# 	 "02020" 0.0001 spices, garlic powder
#
#
#
# 1 cup plain whole-milk Greek yogurt
# 	 "01287" 0.6743 yogurt, greek, plain, lowfat
# 	 "01116" 0.2759 yogurt, plain, whole milk
# 	 "01256" 0.0208 yogurt, greek, plain, nonfat (includes foods for usda's food distribution program)
#
#
#
# 3/4 cup whole milk
# 	 "01077" 0.9569 milk, whole, 3.25% milkfat, with added vitamin d
# 	 "14312" 0.0242 beverages, malted drink mix, natural, powder, prepared with whole milk
# 	 "01085" 0.0053 milk, nonfat, fluid, with added vitamin a and vitamin d (fat free or skim)
#
#
#
# 3 oranges
# 	 "09202" 0.5866 oranges, raw, navels (includes foods for usda's food distribution program)
# 	 "09201" 0.1402 oranges, raw, california, valencias
# 	 "09203" 0.0792 oranges, raw, florida
#
#
#
# Lemon juice (optional)
# 	 "09152" 0.8657 lemon juice, raw
# 	 "09150" 0.1185 lemons, raw, without peel
# 	 "09156" 0.0058 lemon peel, raw
#
#
#
#
#
# RECIPE_85064
# 3 tablespoons butter or margarine
# 	 "01001" 0.9877 butter, salted
# 	 "12695" 0.0027 nuts, almond butter, plain, with salt added
# 	 "04611" 0.0023 margarine, regular, 80% fat, composite, tub, with salt
#
#
#
# 1 package (10 oz. about 40) marshmallows
# 	 "19116" 0.944 candies, marshmallows
# 	 "06626" 0.0071 sauce, pesto, ready-to-serve, refrigerated
# 	 "18363" 0.0052 tortillas, ready-to-bake or -fry, corn
#
#
#
# - OR -
# 	 "14037" 0.2124 alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 80 proof
# 	 "11529" 0.0645 tomatoes, red, ripe, raw, year round average
# 	 "01123" 0.0358 egg, whole, raw, fresh
#
#
#
# 4 cups miniature marshmallows
# 	 "19116" 0.9888 candies, marshmallows
# 	 "12142" 0.0008 nuts, pecans
# 	 "14050" 0.0005 alcoholic beverage, distilled, rum, 80 proof
#
#
#
# 6 cups KELLOGGS® COCOA KRISPIES® cereal
# 	 "19165" 0.972 cocoa, dry powder, unsweetened
# 	 "04501" 0.0064 oil, cocoa butter
# 	 "04708" 0.0035 mayonnaise, reduced fat, with olive oil
#
#
# "08177"
# Creamy peanut butter
# 	 "16399" 0.9516 peanut butter with omega-3, creamy
# 	 "16167" 0.0306 peanut butter, smooth (includes foods for usda's food distribution program)
# 	 "16097" 0.0086 peanut butter, chunk style, with salt
#
#
#
# KELLOGGS® COCOA KRISPIES® cereal
# 	 "19165" 0.972 cocoa, dry powder, unsweetened
# 	 "04501" 0.0064 oil, cocoa butter
# 	 "04708" 0.0035 mayonnaise, reduced fat, with olive oil
#
#
# "08177"
# Pretzel twists
# 	 "14037" 0.0494 alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 80 proof
# 	 "14096" 0.0354 alcoholic beverage, wine, table, red
# 	 "09202" 0.0285 oranges, raw, navels (includes foods for usda's food distribution program)
#
#
# "43109"
# Pretzel sticks
# 	 "14037" 0.0494 alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 80 proof
# 	 "14096" 0.0354 alcoholic beverage, wine, table, red
# 	 "09202" 0.0285 oranges, raw, navels (includes foods for usda's food distribution program)
#
#
# "43109"
# Canned frosting or decorating gel
# 	 "19230" 0.3349 frostings, vanilla, creamy, ready-to-eat
# 	 "11135" 0.0389 cauliflower, raw
# 	 "09139" 0.0305 guavas, common, raw
#
#
#
# Assorted candies
# 	 "14037" 0.0525 alcoholic beverage, distilled, all (gin, rum, vodka, whiskey) 80 proof
# 	 "14096" 0.0332 alcoholic beverage, wine, table, red
# 	 "09202" 0.0295 oranges, raw, navels (includes foods for usda's food distribution program)
#
#
# "19919"

# %%
len(nlp_df)
# Out:
# 1107
